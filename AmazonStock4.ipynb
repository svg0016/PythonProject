# %% [markdown]
# <a href="https://colab.research.google.com/github/svg0016/PythonProject/blob/main/AmazonStock4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This program uses 

#Import Libraries
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')


#Get the stock quote
df = web.DataReader('AMZN', data_source='yahoo', start='2018-01-02', end= '2020-12-21')

#Show the data
df
# Out:
#                    High          Low  ...   Volume    Adj Close
# Date                                  ...
# 2018-01-02  1190.000000  1170.510010  ...  2694500  1189.010010
# 2018-01-03  1205.489990  1188.300049  ...  3108800  1204.199951
# 2018-01-04  1215.869995  1204.660034  ...  3022100  1209.589966
# 2018-01-05  1229.140015  1210.000000  ...  3544700  1229.140015
# 2018-01-08  1253.079956  1232.030029  ...  4279500  1246.869995
# ...                 ...          ...  ...      ...          ...
# 2020-12-15  3188.500000  3130.489990  ...  3323700  3165.120117
# 2020-12-16  3247.000000  3163.679932  ...  4427600  3240.959961
# 2020-12-17  3263.510010  3221.000000  ...  3474300  3236.080078
# 2020-12-18  3249.419922  3171.600098  ...  5995700  3201.649902
# 2020-12-21  3226.969971  3166.000000  ...  3828300  3206.179932
#
# [749 rows x 6 columns]

# %%
#Get the number of rows and colums in the data set
df.shape
# Out:
# (749, 6)

# %%
#Visualize the closing price history
plt.figure(figsize=(16,8))
plt.title('Closing Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize= 18)
plt.ylabel('ClosingPrice ($)USD', fontsize= 18)
plt.show()

# %%
#Create a new dataframe with only the 'Close column
data = df.filter(['Close'])
#Convert the dataframe to a numpy array
dataset = data.values
#Get the number of rows to train the model on
training_data_len = math.ceil( len(dataset)*.80 )

training_data_len
# Out:
# 600

# %%
#Scale the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.        ],
#        [0.00648467],
#        [0.00878569],
#        [0.01713171],
#        [0.02470073],
#        [0.02718957],
#        [0.02788543],
#        [0.03742681],
#        [0.0496021 ],
#        [0.04945697],
#        [0.04524769],
#        [0.04453046],
#        [0.04506837],
#        [0.05904102],
#        [0.07408089],
#        [0.07193354],
#        [0.08065946],
#        [0.09094792],
#        [0.09762045],
#        [0.10621828],
#        [0.11179796],
#        [0.08580369],
#        [0.10285854],
#        [0.08580369],
#        [0.10836135],
#        [0.09723623],
#        [0.06894093],
#        [0.06428765],
#        [0.08419425],
#        [0.09626714],
#        [0.11186628],
#        [0.11643842],
#        [0.11085874],
#        [0.11925171],
#        [0.12547175],
#        [0.12650483],
#        [0.13276327],
#        [0.14213382],
#        [0.13787759],
#        [0.13807822],
#        [0.12996702],
#        [0.13287   ],
#        [0.1428425 ],
#        [0.14883199],
#        [0.15197401],
#        [0.15490257],
#        [0.16644184],
#        [0.17476649],
#        [0.1704078 ],
#        [0.17161165],
#        [0.16790609],
#        [0.16336387],
#        [0.15194415],
#        [0.16969485],
#        [0.16770973],
#        [0.15193988],
#        [0.13086784],
#        [0.15661019],
#        [0.13150392],
#        [0.10348613],
#        [0.11028242],
#        [0.07811512],
#        [0.08667887],
#        [0.09458511],
#        [0.11216509],
#        [0.09230545],
#        [0.09266831],
#        [0.10553524],
#        [0.10162055],
#        [0.11077765],
#        [0.10321717],
#        [0.10778931],
#        [0.1343983 ],
#        [0.1446483 ],
#        [0.15705847],
#        [0.14449889],
#        [0.14038779],
#        [0.11572547],
#        [0.11575965],
#        [0.14043047],
#        [0.16376513],
#        [0.16099452],
#        [0.1678805 ],
#        [0.16251006],
#        [0.16353459],
#        [0.16732123],
#        [0.17551357],
#        [0.17220506],
#        [0.17886904],
#        [0.17933008],
#        [0.17669611],
#        [0.17611125],
#        [0.1652593 ],
#        [0.17002358],
#        [0.16766705],
#        [0.16451222],
#        [0.16924658],
#        [0.16751337],
#        [0.17624784],
#        [0.17676438],
#        [0.1797869 ],
#        [0.18094807],
#        [0.18607948],
#        [0.18809873],
#        [0.19318746],
#        [0.20331792],
#        [0.21658611],
#        [0.21632998],
#        [0.21357646],
#        [0.21130957],
#        [0.2134996 ],
#        [0.2176107 ],
#        [0.22021908],
#        [0.22833028],
#        [0.22496199],
#        [0.22830042],
#        [0.23299211],
#        [0.23952373],
#        [0.23104539],
#        [0.22483395],
#        [0.20241288],
#        [0.21434059],
#        [0.20128584],
#        [0.21876332],
#        [0.21805897],
#        [0.2240271 ],
#        [0.2155658 ],
#        [0.21802906],
#        [0.22268233],
#        [0.23480218],
#        [0.23653112],
#        [0.24162412],
#        [0.25939192],
#        [0.26639745],
#        [0.27043595],
#        [0.27958883],
#        [0.27915765],
#        [0.26637181],
#        [0.26668344],
#        [0.26168867],
#        [0.27331756],
#        [0.2879903 ],
#        [0.2642501 ],
#        [0.26820752],
#        [0.25196375],
#        [0.25120385],
#        [0.25962674],
#        [0.2754905 ],
#        [0.2707775 ],
#        [0.28121959],
#        [0.28750789],
#        [0.29777071],
#        [0.30289358],
#        [0.29767681],
#        [0.30190313],
#        [0.31191409],
#        [0.29610577],
#        [0.29777071],
#        [0.295935  ],
#        [0.29358275],
#        [0.29644732],
#        [0.30561723],
#        [0.30476342],
#        [0.30582641],
#        [0.31534215],
#        [0.3175364 ],
#        [0.34540479],
#        [0.34723195],
#        [0.35164187],
#        [0.36308295],
#        [0.34400452],
#        [0.32841826],
#        [0.32575432],
#        [0.32017897],
#        [0.34073019],
#        [0.34194686],
#        [0.34189136],
#        [0.33348984],
#        [0.30695345],
#        [0.32104987],
#        [0.31480424],
#        [0.32243731],
#        [0.30993324],
#        [0.31819385],
#        [0.3353512 ],
#        [0.33547924],
#        [0.35175714],
#        [0.34749663],
#        [0.34807722],
#        [0.33396803],
#        [0.32604891],
#        [0.30754685],
#        [0.29910693],
#        [0.28833612],
#        [0.29085482],
#        [0.24173085],
#        [0.22640921],
#        [0.2559724 ],
#        [0.24416419],
#        [0.26935587],
#        [0.27438055],
#        [0.24833506],
#        [0.24547909],
#        [0.25626699],
#        [0.2474727 ],
#        [0.2028611 ],
#        [0.25322316],
#        [0.19372964],
#        [0.14936135],
#        [0.14574975],
#        [0.17460426],
#        [0.20342892],
#        [0.20342892],
#        [0.18732179],
#        [0.19372964],
#        [0.2418333 ],
#        [0.24158571],
#        [0.22345079],
#        [0.19118525],
#        [0.18876046],
#        [0.17503117],
#        [0.18375281],
#        [0.17264051],
#        [0.13800995],
#        [0.1308251 ],
#        [0.13990539],
#        [0.13364272],
#        [0.16748346],
#        [0.16752192],
#        [0.20864569],
#        [0.2068612 ],
#        [0.21394787],
#        [0.24903519],
#        [0.20465413],
#        [0.21779851],
#        [0.18788955],
#        [0.19296974],
#        [0.19391318],
#        [0.20257938],
#        [0.20037653],
#        [0.17200015],
#        [0.14168988],
#        [0.15474035],
#        [0.13066288],
#        [0.11604137],
#        [0.08044601],
#        [0.06614895],
#        [0.12034034],
#        [0.11638719],
#        [0.1233799 ],
#        [0.13360426],
#        [0.14946808],
#        [0.13288282],
#        [0.16494767],
#        [0.18805178],
#        [0.19960808],
#        [0.20082053],
#        [0.1994544 ],
#        [0.1927691 ],
#        [0.18280082],
#        [0.20728388],
#        [0.21121994],
#        [0.2152499 ],
#        [0.21652207],
#        [0.18918736],
#        [0.19253856],
#        [0.19890373],
#        [0.20558048],
#        [0.19162925],
#        [0.17284114],
#        [0.20552076],
#        [0.22614026],
#        [0.18665152],
#        [0.18967404],
#        [0.20056013],
#        [0.19264101],
#        [0.18158843],
#        [0.17042484],
#        [0.17161165],
#        [0.19168047],
#        [0.19253001],
#        [0.18512322],
#        [0.17884768],
#        [0.18722783],
#        [0.1848884 ],
#        [0.18375281],
#        [0.18892696],
#        [0.18954168],
#        [0.19099316],
#        [0.19299532],
#        [0.19245742],
#        [0.20607571],
#        [0.2165093 ],
#        [0.21491268],
#        [0.2048889 ],
#        [0.18653197],
#        [0.18433345],
#        [0.20560185],
#        [0.20666057],
#        [0.21422109],
#        [0.21226156],
#        [0.22342087],
#        [0.2361384 ],
#        [0.24454841],
#        [0.25966942],
#        [0.26905706],
#        [0.24579499],
#        [0.24984632],
#        [0.25390192],
#        [0.24619199],
#        [0.24948773],
#        [0.25261693],
#        [0.26689262],
#        [0.26680299],
#        [0.26967178],
#        [0.26888629],
#        [0.2767499 ],
#        [0.28212035],
#        [0.27613513],
#        [0.28104027],
#        [0.27964855],
#        [0.27921743],
#        [0.2799901 ],
#        [0.28774698],
#        [0.28850684],
#        [0.28717062],
#        [0.29810798],
#        [0.31367293],
#        [0.30427247],
#        [0.30448592],
#        [0.3251396 ],
#        [0.31993138],
#        [0.31484692],
#        [0.30844334],
#        [0.30387543],
#        [0.33018987],
#        [0.32510547],
#        [0.3124904 ],
#        [0.3111115 ],
#        [0.30346989],
#        [0.29924779],
#        [0.27051709],
#        [0.2779623 ],
#        [0.29120918],
#        [0.30675704],
#        [0.29029132],
#        [0.28600945],
#        [0.28539046],
#        [0.28631259],
#        [0.26744334],
#        [0.27077323],
#        [0.27638704],
#        [0.26902715],
#        [0.26780193],
#        [0.25019209],
#        [0.21502363],
#        [0.23076367],
#        [0.23458018],
#        [0.24135089],
#        [0.2625553 ],
#        [0.28671813],
#        [0.2880287 ],
#        [0.28445124],
#        [0.29084632],
#        [0.29057737],
#        [0.29756153],
#        [0.30411025],
#        [0.3072779 ],
#        [0.31129077],
#        [0.30834944],
#        [0.30945938],
#        [0.29424874],
#        [0.30259898],
#        [0.30535255],
#        [0.300806  ],
#        [0.31299839],
#        [0.31817253],
#        [0.32017469],
#        [0.32184391],
#        [0.32586105],
#        [0.34122115],
#        [0.35364835],
#        [0.34667268],
#        [0.35091187],
#        [0.35517665],
#        [0.35044229],
#        [0.34281349],
#        [0.33678132],
#        [0.33106932],
#        [0.34008129],
#        [0.34386366],
#        [0.34656173],
#        [0.33503951],
#        [0.32190368],
#        [0.30884034],
#        [0.30289785],
#        [0.28934361],
#        [0.28445124],
#        [0.27075613],
#        [0.24594867],
#        [0.2556394 ],
#        [0.25801729],
#        [0.27487578],
#        [0.26407078],
#        [0.25439715],
#        [0.27122572],
#        [0.24502227],
#        [0.25064036],
#        [0.25766293],
#        [0.26771657],
#        [0.26142399],
#        [0.27088423],
#        [0.26282425],
#        [0.23932737],
#        [0.24754529],
#        [0.24453986],
#        [0.24557299],
#        [0.25502896],
#        [0.25071295],
#        [0.25649749],
#        [0.26109954],
#        [0.27821843],
#        [0.27514046],
#        [0.27421833],
#        [0.26960778],
#        [0.27064941],
#        [0.2794266 ],
#        [0.2776293 ],
#        [0.26418178],
#        [0.27046159],
#        [0.26828861],
#        [0.27001332],
#        [0.25834175],
#        [0.25455937],
#        [0.23590785],
#        [0.24731475],
#        [0.23515222],
#        [0.22900905],
#        [0.23347451],
#        [0.23336351],
#        [0.22379228],
#        [0.22856938],
#        [0.23507113],
#        [0.23208707],
#        [0.22049658],
#        [0.22753197],
#        [0.22679343],
#        [0.23177117],
#        [0.23369651],
#        [0.24690921],
#        [0.25119963],
#        [0.25549   ],
#        [0.24269566],
#        [0.25471305],
#        [0.24620481],
#        [0.24468505],
#        [0.25262975],
#        [0.24432641],
#        [0.25105017],
#        [0.24491554],
#        [0.25229248],
#        [0.2508709 ],
#        [0.25718052],
#        [0.26282425],
#        [0.26156485],
#        [0.25902906],
#        [0.25579736],
#        [0.25480696],
#        [0.2487321 ],
#        [0.25144294],
#        [0.24081726],
#        [0.24145335],
#        [0.23500282],
#        [0.24056968],
#        [0.24068068],
#        [0.23758134],
#        [0.2329622 ],
#        [0.23766243],
#        [0.249667  ],
#        [0.2595285 ],
#        [0.26873688],
#        [0.2611764 ],
#        [0.25297979],
#        [0.24801061],
#        [0.24405319],
#        [0.23542545],
#        [0.24017263],
#        [0.23928041],
#        [0.23488327],
#        [0.23894314],
#        [0.24389951],
#        [0.24415991],
#        [0.24769043],
#        [0.25684758],
#        [0.25401719],
#        [0.25753916],
#        [0.25507164],
#        [0.25784652],
#        [0.25622853],
#        [0.29019314],
#        [0.29063287],
#        [0.28085245],
#        [0.28125799],
#        [0.30267585],
#        [0.29283994],
#        [0.30475488],
#        [0.30645395],
#        [0.30009733],
#        [0.30397366],
#        [0.29633632],
#        [0.29981133],
#        [0.29047914],
#        [0.28731153],
#        [0.29410783],
#        [0.28846416],
#        [0.30011014],
#        [0.29817198],
#        [0.29694249],
#        [0.28714931],
#        [0.27293334],
#        [0.28356756],
#        [0.28559537],
#        [0.29100855],
#        [0.34993852],
#        [0.3480089 ],
#        [0.36742027],
#        [0.36323663],
#        [0.36765936],
#        [0.38006098],
#        [0.40338277],
#        [0.41059325],
#        [0.41452076],
#        [0.41019626],
#        [0.40379268],
#        [0.41267223],
#        [0.41888372],
#        [0.41157516],
#        [0.387186  ],
#        [0.35018188],
#        [0.33457847],
#        [0.33750276],
#        [0.296823  ],
#        [0.29658818],
#        [0.32655691],
#        [0.30736326],
#        [0.3358976 ],
#        [0.31378393],
#        [0.3039907 ],
#        [0.26109526],
#        [0.30003328],
#        [0.2697401 ],
#        [0.20815901],
#        [0.25443128],
#        [0.21351242],
#        [0.26418178],
#        [0.27364202],
#        [0.29538433],
#        [0.28051091],
#        [0.30473351],
#        [0.32064428],
#        [0.29748039],
#        [0.32721436],
#        [0.30356807],
#        [0.33082596],
#        [0.32475111],
#        [0.30681254],
#        [0.311564  ],
#        [0.30633868],
#        [0.34518706],
#        [0.35116801],
#        [0.36457284],
#        [0.36447039],
#        [0.41830746],
#        [0.46716675],
#        [0.47756611],
#        [0.52047436],
#        [0.5063054 ],
#        [0.51425015],
#        [0.48629213],
#        [0.50139172],
#        [0.51674321],
#        [0.52134099],
#        [0.5067323 ],
#        [0.48029836],
#        [0.50532777],
#        [0.54856902],
#        [0.46832792],
#        [0.48111371],
#        [0.48188644],
#        [0.49617067],
#        [0.50315062],
#        [0.50827348],
#        [0.52082018],
#        [0.49859974],
#        [0.50328288],
#        [0.51221808],
#        [0.52115318],
#        [0.52818857],
#        [0.5380373 ],
#        [0.55878911],
#        [0.53693158],
#        [0.53272225],
#        [0.52631023],
#        [0.52141353],
#        [0.51744767],
#        [0.53506606],
#        [0.5473054 ],
#        [0.54789021],
#        [0.55044736],
#        [0.54284853],
#        [0.55241117],
#        [0.56993993],
#        [0.60272627],
#        [0.62261572],
#        [0.58441197],
#        [0.57888785],
#        [0.59069601],
#        [0.60887794],
#        [0.61985366],
#        [0.62540343],
#        [0.63438126],
#        [0.65094948],
#        [0.67254655],
#        [0.65973512],
#        [0.66835014],
#        [0.64200583],
#        [0.63667369],
#        [0.67016022],
#        [0.72133757],
#        [0.72628972],
#        [0.7974719 ],
#        [0.77317248],
#        [0.80774754],
#        [0.85108687],
#        [0.85850226],
#        [0.81751936],
#        [0.80898125],
#        [0.7769079 ],
#        [0.77307847],
#        [0.75688598],
#        [0.85715328],
#        [0.83215795],
#        [0.81577327],
#        [0.76737935],
#        [0.77692489],
#        [0.79669063],
#        [0.77326212],
#        [0.78743535],
#        [0.795269  ],
#        [0.84342394],
#        [0.82088759],
#        [0.8323885 ],
#        [0.86064961],
#        [0.8691749 ],
#        [0.84461075],
#        [0.83637146],
#        [0.80755962],
#        [0.84238231],
#        [0.8418615 ],
#        [0.83631173],
#        [0.85099296],
#        [0.90652483],
#        [0.88432149],
#        [0.90007008],
#        [0.89466967],
#        [0.90437749],
#        [0.92103961],
#        [0.96174935],
#        [0.94388332],
#        [0.94465177],
#        [0.9656384 ],
#        [0.98619822],
#        [1.        ],
#        [0.93022235],
#        [0.89889609],
#        [0.83708873],
#        [0.88779228],
#        [0.84787664],
#        [0.82273613],
#        [0.81707963],
#        [0.83977388],
#        [0.80646255],
#        [0.77684808],
#        [0.75387201],
#        [0.75624563],
#        [0.82818771],
#        [0.77306148],
#        [0.78156968],
#        [0.81373266],
#        [0.84742409],
#        [0.83497119],
#        [0.83661482],
#        [0.86757827],
#        [0.82648437],
#        [0.85816072],
#        [0.81579464],
#        [0.85666228],
#        [0.85446803],
#        [0.89549356],
#        [0.96221034],
#        [0.96250915],
#        [0.92839091],
#        [0.91769264],
#        [0.88954253],
#        [0.86158023],
#        [0.86576393],
#        [0.85207304],
#        [0.84842726],
#        [0.8603806 ],
#        [0.86150769],
#        [0.89535703],
#        [0.84261286],
#        [0.86320249],
#        [0.78855379],
#        [0.77503373],
#        [0.79378765],
#        [0.87607365],
#        [0.91058471],
#        [0.90604675],
#        [0.83448457],
#        [0.78807144],
#        [0.83177368],
#        [0.82020033],
#        [0.8281109 ],
#        [0.82907144],
#        [0.83103514],
#        [0.81814262],
#        [0.82307767],
#        [0.81555555],
#        [0.81512437],
#        [0.82352167],
#        [0.8521286 ],
#        [0.85651292],
#        [0.84485839],
#        [0.86707455],
#        [0.86000925],
#        [0.85283722],
#        [0.8425275 ],
#        [0.84057224],
#        [0.84880726],
#        [0.81760472],
#        [0.81644782],
#        [0.82282149],
#        [0.84013252],
#        [0.84361186],
#        [0.87598829],
#        [0.87390504],
#        [0.85920661],
#        [0.86114051]])

# %%
#Create the traiing data set
#Creat the scaled training data set
train_data = scaled_data[0:training_data_len, :]
#Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(70, len(train_data)):
    x_train.append(train_data[i-70:i, 0])
    y_train.append(train_data[i,0])

    if i<=71:
        print(x_train)
        print(y_train)
        print()
# Out:
# [array([0.        , 0.00648467, 0.00878569, 0.01713171, 0.02470073,
#        0.02718957, 0.02788543, 0.03742681, 0.0496021 , 0.04945697,
#        0.04524769, 0.04453046, 0.04506837, 0.05904102, 0.07408089,
#        0.07193354, 0.08065946, 0.09094792, 0.09762045, 0.10621828,
#        0.11179796, 0.08580369, 0.10285854, 0.08580369, 0.10836135,
#        0.09723623, 0.06894093, 0.06428765, 0.08419425, 0.09626714,
#        0.11186628, 0.11643842, 0.11085874, 0.11925171, 0.12547175,
#        0.12650483, 0.13276327, 0.14213382, 0.13787759, 0.13807822,
#        0.12996702, 0.13287   , 0.1428425 , 0.14883199, 0.15197401,
#        0.15490257, 0.16644184, 0.17476649, 0.1704078 , 0.17161165,
#        0.16790609, 0.16336387, 0.15194415, 0.16969485, 0.16770973,
#        0.15193988, 0.13086784, 0.15661019, 0.13150392, 0.10348613,
#        0.11028242, 0.07811512, 0.08667887, 0.09458511, 0.11216509,
#        0.09230545, 0.09266831, 0.10553524, 0.10162055, 0.11077765])]
# [0.1032171732658066]
#
# [array([0.        , 0.00648467, 0.00878569, 0.01713171, 0.02470073,
#        0.02718957, 0.02788543, 0.03742681, 0.0496021 , 0.04945697,
#        0.04524769, 0.04453046, 0.04506837, 0.05904102, 0.07408089,
#        0.07193354, 0.08065946, 0.09094792, 0.09762045, 0.10621828,
#        0.11179796, 0.08580369, 0.10285854, 0.08580369, 0.10836135,
#        0.09723623, 0.06894093, 0.06428765, 0.08419425, 0.09626714,
#        0.11186628, 0.11643842, 0.11085874, 0.11925171, 0.12547175,
#        0.12650483, 0.13276327, 0.14213382, 0.13787759, 0.13807822,
#        0.12996702, 0.13287   , 0.1428425 , 0.14883199, 0.15197401,
#        0.15490257, 0.16644184, 0.17476649, 0.1704078 , 0.17161165,
#        0.16790609, 0.16336387, 0.15194415, 0.16969485, 0.16770973,
#        0.15193988, 0.13086784, 0.15661019, 0.13150392, 0.10348613,
#        0.11028242, 0.07811512, 0.08667887, 0.09458511, 0.11216509,
#        0.09230545, 0.09266831, 0.10553524, 0.10162055, 0.11077765]), array([0.00648467, 0.00878569, 0.01713171, 0.02470073, 0.02718957,
#        0.02788543, 0.03742681, 0.0496021 , 0.04945697, 0.04524769,
#        0.04453046, 0.04506837, 0.05904102, 0.07408089, 0.07193354,
#        0.08065946, 0.09094792, 0.09762045, 0.10621828, 0.11179796,
#        0.08580369, 0.10285854, 0.08580369, 0.10836135, 0.09723623,
#        0.06894093, 0.06428765, 0.08419425, 0.09626714, 0.11186628,
#        0.11643842, 0.11085874, 0.11925171, 0.12547175, 0.12650483,
#        0.13276327, 0.14213382, 0.13787759, 0.13807822, 0.12996702,
#        0.13287   , 0.1428425 , 0.14883199, 0.15197401, 0.15490257,
#        0.16644184, 0.17476649, 0.1704078 , 0.17161165, 0.16790609,
#        0.16336387, 0.15194415, 0.16969485, 0.16770973, 0.15193988,
#        0.13086784, 0.15661019, 0.13150392, 0.10348613, 0.11028242,
#        0.07811512, 0.08667887, 0.09458511, 0.11216509, 0.09230545,
#        0.09266831, 0.10553524, 0.10162055, 0.11077765, 0.10321717])]
# [0.1032171732658066, 0.10778931223431754]

# %%
#Convert the x_train and y_train to numpy arrays
x_train,y_train = np.array(x_train), np.array(y_train)

# %%
#Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
#x_test.shape[0] = number of rows
#x_test.shape[1] = number of columns/timestamps
#1 = number of features, close price

# %%
#Build the LSTM(Long Term Short Memory) model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(50, return_sequences= False))
model.add(Dense(25))
model.add(Dense(1))

# %%
#Compile the model
model.compile(optimizer= 'adam', loss='mean_squared_error')

# %%
#Train the Model
model.fit(x_train, y_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 53/53 [==============================] - 4s 34ms/step - loss: 0.0167
# Epoch 2/100
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0017
# Epoch 3/100
# 53/53 [==============================] - 2s 35ms/step - loss: 9.4082e-04
# Epoch 4/100
# 53/53 [==============================] - 2s 34ms/step - loss: 0.0011
# Epoch 5/100
# 53/53 [==============================] - 2s 35ms/step - loss: 0.0010
# Epoch 6/100
# 53/53 [==============================] - 2s 34ms/step - loss: 7.6818e-04
# Epoch 7/100
# 53/53 [==============================] - 2s 35ms/step - loss: 8.5695e-04
# Epoch 8/100
# 53/53 [==============================] - 2s 35ms/step - loss: 7.0495e-04
# Epoch 9/100
# 53/53 [==============================] - 2s 34ms/step - loss: 7.1502e-04
# Epoch 10/100
# 53/53 [==============================] - 2s 35ms/step - loss: 5.6204e-04
# Epoch 11/100
# 53/53 [==============================] - 2s 35ms/step - loss: 6.0101e-04
# Epoch 12/100
# 53/53 [==============================] - 2s 35ms/step - loss: 5.6706e-04
# Epoch 13/100
# 53/53 [==============================] - 2s 35ms/step - loss: 5.7782e-04
# Epoch 14/100
# 53/53 [==============================] - 2s 35ms/step - loss: 7.3013e-04
# Epoch 15/100
# 53/53 [==============================] - 2s 35ms/step - loss: 5.5375e-04
# Epoch 16/100
# 53/53 [==============================] - 2s 35ms/step - loss: 4.1524e-04
# Epoch 17/100
# 53/53 [==============================] - 2s 34ms/step - loss: 4.0736e-04
# Epoch 18/100
# 53/53 [==============================] - 2s 35ms/step - loss: 5.5530e-04
# Epoch 19/100
# 53/53 [==============================] - 2s 35ms/step - loss: 4.2520e-04
# Epoch 20/100
# 53/53 [==============================] - 2s 35ms/step - loss: 4.5779e-04
# Epoch 21/100
# 53/53 [==============================] - 2s 34ms/step - loss: 5.2797e-04
# Epoch 22/100
# 53/53 [==============================] - 2s 35ms/step - loss: 4.1176e-04
# Epoch 23/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.4356e-04
# Epoch 24/100
# 53/53 [==============================] - 2s 35ms/step - loss: 4.6418e-04
# Epoch 25/100
# 53/53 [==============================] - 2s 34ms/step - loss: 3.4028e-04
# Epoch 26/100
# 53/53 [==============================] - 2s 34ms/step - loss: 3.1897e-04
# Epoch 27/100
# 53/53 [==============================] - 2s 35ms/step - loss: 4.3652e-04
# Epoch 28/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.5974e-04
# Epoch 29/100
# 53/53 [==============================] - 2s 36ms/step - loss: 3.3205e-04
# Epoch 30/100
# 53/53 [==============================] - 2s 34ms/step - loss: 3.3395e-04
# Epoch 31/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.1871e-04
# Epoch 32/100
# 53/53 [==============================] - 2s 34ms/step - loss: 3.6307e-04
# Epoch 33/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.6204e-04
# Epoch 34/100
# 53/53 [==============================] - 2s 35ms/step - loss: 4.0390e-04
# Epoch 35/100
# 53/53 [==============================] - 2s 34ms/step - loss: 2.8932e-04
# Epoch 36/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.5293e-04
# Epoch 37/100
# 53/53 [==============================] - 2s 34ms/step - loss: 2.7740e-04
# Epoch 38/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.4726e-04
# Epoch 39/100
# 53/53 [==============================] - 2s 36ms/step - loss: 2.7455e-04
# Epoch 40/100
# 53/53 [==============================] - 2s 36ms/step - loss: 3.7328e-04
# Epoch 41/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.1893e-04
# Epoch 42/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.6697e-04
# Epoch 43/100
# 53/53 [==============================] - 2s 34ms/step - loss: 3.1156e-04
# Epoch 44/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.6773e-04
# Epoch 45/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.0491e-04
# Epoch 46/100
# 53/53 [==============================] - 2s 34ms/step - loss: 2.9671e-04
# Epoch 47/100
# 53/53 [==============================] - 2s 34ms/step - loss: 2.9978e-04
# Epoch 48/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.1113e-04
# Epoch 49/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.7474e-04
# Epoch 50/100
# 53/53 [==============================] - 2s 36ms/step - loss: 3.3290e-04
# Epoch 51/100
# 53/53 [==============================] - 2s 36ms/step - loss: 3.8121e-04
# Epoch 52/100
# 53/53 [==============================] - 2s 36ms/step - loss: 3.2995e-04
# Epoch 53/100
# 53/53 [==============================] - 2s 36ms/step - loss: 2.3862e-04
# Epoch 54/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.9142e-04
# Epoch 55/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.9772e-04
# Epoch 56/100
# 53/53 [==============================] - 2s 34ms/step - loss: 2.6094e-04
# Epoch 57/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.4006e-04
# Epoch 58/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.3850e-04
# Epoch 59/100
# 53/53 [==============================] - 2s 34ms/step - loss: 3.0259e-04
# Epoch 60/100
# 53/53 [==============================] - 2s 34ms/step - loss: 3.3832e-04
# Epoch 61/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.7712e-04
# Epoch 62/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.1083e-04
# Epoch 63/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.2720e-04
# Epoch 64/100
# 53/53 [==============================] - 2s 36ms/step - loss: 3.3886e-04
# Epoch 65/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.8934e-04
# Epoch 66/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.8774e-04
# Epoch 67/100
# 53/53 [==============================] - 2s 36ms/step - loss: 2.8116e-04
# Epoch 68/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.2866e-04
# Epoch 69/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.7138e-04
# Epoch 70/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.8699e-04
# Epoch 71/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.9807e-04
# Epoch 72/100
# 53/53 [==============================] - 2s 36ms/step - loss: 3.0739e-04
# Epoch 73/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.4490e-04
# Epoch 74/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.2406e-04
# Epoch 75/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.7736e-04
# Epoch 76/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.9590e-04
# Epoch 77/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.6923e-04
# Epoch 78/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.5113e-04
# Epoch 79/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.6328e-04
# Epoch 80/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.7315e-04
# Epoch 81/100
# 53/53 [==============================] - 2s 36ms/step - loss: 2.7810e-04
# Epoch 82/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.5560e-04
# Epoch 83/100
# 53/53 [==============================] - 2s 36ms/step - loss: 2.6225e-04
# Epoch 84/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.9729e-04
# Epoch 85/100
# 53/53 [==============================] - 2s 34ms/step - loss: 2.7477e-04
# Epoch 86/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.2506e-04
# Epoch 87/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.1093e-04
# Epoch 88/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.7657e-04
# Epoch 89/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.6778e-04
# Epoch 90/100
# 53/53 [==============================] - 2s 34ms/step - loss: 3.7826e-04
# Epoch 91/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.2201e-04
# Epoch 92/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.9922e-04
# Epoch 93/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.2732e-04
# Epoch 94/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.9957e-04
# Epoch 95/100
# 53/53 [==============================] - 2s 34ms/step - loss: 3.2945e-04
# Epoch 96/100
# 53/53 [==============================] - 2s 34ms/step - loss: 2.8151e-04
# Epoch 97/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.6332e-04
# Epoch 98/100
# 53/53 [==============================] - 2s 35ms/step - loss: 3.4450e-04
# Epoch 99/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.9719e-04
# Epoch 100/100
# 53/53 [==============================] - 2s 35ms/step - loss: 2.4109e-04

# %%
#Create the testing data set
#Create a new array conaining scaled values from index 748 997
test_data = scaled_data[training_data_len - 70: , :]
#Create the data sets x_test and y_test
x_test = []
y_test = dataset[training_data_len:, :]

for i in range(70, len(test_data)):
  x_test.append(test_data[i-70:i, 0])

# %%
#Convert the data to a numpy array
x_test = np.array(x_test)

# %%
#Reshape the Data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
#x_test.shape[0] = number of rows
#x_test.shape[1] = number of columns/timestamps
#1 = number of features, close price

# %%
#Get the models predicted price values
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)#Unscaling the predictions

# %%
#Get the root mean squared error(RMSE)
rmse = np.sqrt( np.mean(predictions - y_test )**2)
rmse
# Out:
# 8.857983889995806

# %%
#Plot the data
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
#Visualize the data
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date')
plt.ylabel('Closing Price $USD')
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train','Actual','Predictions'],loc= 'lower right' )
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#Show the valid and predicted prices

valid
# Out:
#                   Close  Predictions
# Date
# 2020-05-21  2446.739990  2490.063721
# 2020-05-22  2436.879883  2434.199707
# 2020-05-26  2421.860107  2421.133057
# 2020-05-27  2410.389893  2405.512207
# 2020-05-28  2401.100098  2393.498779
# ...                 ...          ...
# 2020-12-15  3165.120117  3159.979248
# 2020-12-16  3240.959961  3164.247070
# 2020-12-17  3236.080078  3253.921875
# 2020-12-18  3201.649902  3235.974121
# 2020-12-21  3206.179932  3195.410400
#
# [149 rows x 2 columns]

# %%
#Get the quote
amzn_quote = web.DataReader('AMZN', data_source='yahoo', start='2018-01-02', end='2020-12-21')
#Create a new dataframe
new_df = amzn_quote.filter(['Close'])
#Get the last 60 day closing price values and convert the dataframe to an array
last_60_days = new_df[-60:].values
#Scale the data to be values between 0 and 1
last_60_days_scaled = scaler.transform(last_60_days)
#Create an empty list
X_test = []
#Append the past 60 days
X_test.append(last_60_days_scaled)
#Convert the X_test data set to a numpy array
X_test = np.array(X_test)
#Reshape the data
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
#Get the predicted scaled price
pred_price = model.predict(X_test)
#undo the scaling
pred_price = scaler.inverse_transform(pred_price)
print(pred_price)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 70, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 70, 1), dtype=tf.float32, name='lstm_4_input'), name='lstm_4_input', description="created by layer 'lstm_4_input'"), but it was called on an input with incompatible shape (None, 60, 1).
# [[3205.6965]]

# %%
#Get Amazon Current value
amzn_quote2 = web.DataReader('AMZN', data_source='yahoo', start='2020-12-21', end='2020-12-21')
print(amzn_quote2['Close'])
# Out:
# Date
# 2020-12-21    3206.179932
# Name: Close, dtype: float64
